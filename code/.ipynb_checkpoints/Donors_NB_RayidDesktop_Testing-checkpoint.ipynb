# %%
import os
import yaml
import pandas as pd
import sqlalchemy

import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display 
pd.options.display.max_columns = None
# %matplotlib inline

def connect(poolclass=sqlalchemy.pool.QueuePool):
    with open(os.path.join(os.path.join('..', 'config'), 'donors_db_profile.yaml')) as fd:
        config = yaml.load(fd)
        dburl = sqlalchemy.engine.url.URL(
            "postgres",
            host=config["host"],
            username=config["user"],
            database=config["db"],
            password=config["pass"],
            port=config["port"],
        )
        return sqlalchemy.create_engine(dburl, poolclass=poolclass)

conn = connect()


import RecallAdjuster as ra
from importlib import reload
import datetime
from dateutil.relativedelta import relativedelta
import seaborn as sns
# Out:
# /home/hemank/pythonevns/equity/lib/python3.6/site-packages/ipykernel_launcher.py:15: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   from ipykernel import kernelapp as app

# %%
## FOR DONORS
### Train End Time is all end dates
base = datetime.datetime.strptime('2013-06-01', '%Y-%m-%d')   #Corresponding to latest train_end_time
date_pairs = []

# we can make x range to 20 months ago
for x in range(5, -1, -1):
    date_pairs.append(
        (
            (base - relativedelta(months=6*x) - relativedelta(months=6)).strftime('%Y-%m-%d'),
            (base - relativedelta(months=6*x) - relativedelta(months=6)).strftime('%Y-%m-%d')
        )
    )
    date_pairs.append(
        (
            (base - relativedelta(months=6*x) - relativedelta(months=6)).strftime('%Y-%m-%d'),
            (base - relativedelta(months=6*x)).strftime('%Y-%m-%d')
        )
    )

for i in range(0, len(date_pairs), 2):
    print(date_pairs[i], date_pairs[i+1])
# Out:
# ('2010-06-01', '2010-06-01') ('2010-06-01', '2010-12-01')
# ('2010-12-01', '2010-12-01') ('2010-12-01', '2011-06-01')
# ('2011-06-01', '2011-06-01') ('2011-06-01', '2011-12-01')
# ('2011-12-01', '2011-12-01') ('2011-12-01', '2012-06-01')
# ('2012-06-01', '2012-06-01') ('2012-06-01', '2012-12-01')
# ('2012-12-01', '2012-12-01') ('2012-12-01', '2013-06-01')

# %%
import time
start_time = time.time()
myRA = ra.RecallAdjuster(
        engine=conn,
        pg_role='postgres',
        schema='hemank_entity_demos',
        experiment_hashes='0f0abbf0d62a61706253f2ec9769273c',
        date_pairs=date_pairs,
        list_sizes=[50],
        entity_demos='donors',
        demo_col='poverty_level'
)
print("Time Taken="+str(time.time() - start_time))
# Out:
# Time Taken=979.6197872161865

# %%
sql = """
WITH mg_rns AS (
  SELECT *,
         row_number() OVER (PARTITION BY train_end_time, list_size, metric, parameter ORDER BY base_value DESC, base_max_recall_ratio ASC, RANDOM()) AS rn_base,
         row_number() OVER (PARTITION BY train_end_time, list_size, metric, parameter ORDER BY adj_value DESC, adj_max_recall_ratio ASC, RANDOM()) AS rn_adj
  FROM hemank_bias_class_test.model_adjustment_results_poverty_level
  WHERE past_train_end_time = train_end_time
)
, base_mgs AS (
  SELECT * FROM mg_rns WHERE rn_base = 1
)
, adj_mgs AS (
  SELECT * FROM mg_rns WHERE rn_adj = 1
)
-- Simple model selection on last time period, baseline with no recall adjustments
SELECT 'Best Unadjusted Metric - Unadjusted'::VARCHAR(128) AS strategy,
       r.train_end_time, r.past_train_end_time,
       r.list_size, r.metric, r.parameter,
       r.base_value AS value,
       r.base_max_recall_ratio AS max_recall_ratio,
       r.base_recall_low_poverty_to_highest_poverty AS recall_low_to_highest,
       r.base_recall_low_poverty_to_high_poverty AS recall_low_high,
       r.base_recall_low_poverty_to_moderate_poverty AS recall_low_moderate,
       r.base_recall_moderate_poverty_to_high_poverty AS recall_moderate_high,
       r.base_recall_moderate_poverty_to_highest_poverty AS recall_moderate_highest
FROM hemank_bias_class_test.model_adjustment_results_poverty_level r
JOIN base_mgs b
  ON r.model_group_id = b.model_group_id
  AND r.past_train_end_time = b.train_end_time
  AND r.list_size = b.list_size
  AND r.metric = b.metric
  AND r.parameter = b.parameter
WHERE r.train_end_time > r.past_train_end_time

UNION ALL

-- Model selection on last time before adjustment, with adjustment applied
SELECT 'Best Unadjusted Metric - Adjusted'::VARCHAR(128) AS strategy,
       r.train_end_time, r.past_train_end_time,
       r.list_size, r.metric, r.parameter,
       r.adj_value AS value,
       r.adj_max_recall_ratio AS max_recall_ratio,
       r.adj_recall_low_poverty_to_highest_poverty AS recall_low_to_highest,
       r.adj_recall_low_poverty_to_high_poverty AS recall_low_high,
       r.adj_recall_low_poverty_to_moderate_poverty AS recall_low_moderate,
       r.adj_recall_moderate_poverty_to_high_poverty AS recall_moderate_high,
       r.adj_recall_moderate_poverty_to_highest_poverty AS recall_moderate_highest
FROM hemank_bias_class_test.model_adjustment_results_poverty_level r
JOIN base_mgs b
  ON r.model_group_id = b.model_group_id
  AND r.past_train_end_time = b.train_end_time
  AND r.list_size = b.list_size
  AND r.metric = b.metric
  AND r.parameter = b.parameter
WHERE r.train_end_time > r.past_train_end_time

UNION ALL

-- Model selection on last time after adjustment, with adjustment applied
SELECT 'Best Adjusted Metric - Adjusted'::VARCHAR(128) AS strategy,
       r.train_end_time, r.past_train_end_time,
       r.list_size, r.metric, r.parameter,
       r.adj_value AS value,
       r.adj_max_recall_ratio AS max_recall_ratio,
    r.adj_recall_low_poverty_to_highest_poverty AS recall_low_to_highest,
       r.adj_recall_low_poverty_to_high_poverty AS recall_low_high,
       r.adj_recall_low_poverty_to_moderate_poverty AS recall_low_moderate,
       r.adj_recall_moderate_poverty_to_high_poverty AS recall_moderate_high,
       r.adj_recall_moderate_poverty_to_highest_poverty AS recall_moderate_highest
FROM hemank_bias_class_test.model_adjustment_results_poverty_level r
JOIN adj_mgs b
  ON r.model_group_id = b.model_group_id
  AND r.past_train_end_time = b.train_end_time
  AND r.list_size = b.list_size
  AND r.metric = b.metric
  AND r.parameter = b.parameter
WHERE r.train_end_time > r.past_train_end_time
"""

discarded = """
UNION ALL

-- Composite model
SELECT 'Composite Model - Adjusted'::VARCHAR(128) AS strategy,
      future_train_end_time AS train_end_time, past_train_end_time,
      list_size, metric, parameter,
      value,
      max_recall_ratio,
      recall_w_to_b,
      recall_w_to_h,
      recall_b_to_h
FROM kit_bias_class_test.composite_results_race_3way
WHERE future_train_end_time > past_train_end_time
;
"""

ts_df = pd.read_sql(sql, conn)

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='value', hue='strategy', marker="o", ax=ax)
plt.title("Value over Time", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Value over Time')

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='max_recall_ratio', hue='strategy', marker="o", ax=ax)
plt.title("Max Recall Ratio", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Max Recall Ratio')

# %%
print(ts_df.columns)
# Out:
# Index(['strategy', 'train_end_time', 'past_train_end_time', 'list_size',
#        'metric', 'parameter', 'value', 'max_recall_ratio',
#        'recall_low_to_highest', 'recall_low_high', 'recall_low_moderate',
#        'recall_moderate_high', 'recall_moderate_highest'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='recall_low_to_highest', hue='strategy', marker="o", ax=ax)
plt.title("Recall Low to Highest", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Recall Low to Highest')

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='recall_low_high', hue='strategy', marker="o", ax=ax)
plt.title("Recall Low to High", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Recall Low to High')

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='recall_low_moderate', hue='strategy', marker="o", ax=ax)
plt.title("Recall Low to Moderate", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Recall Low to Moderate')

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='recall_moderate_highest', hue='strategy', marker="o", ax=ax)
plt.title("Recall Moderate to Highest", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Recall Moderate to Highest')

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.lineplot(data=ts_df, x='train_end_time', y='recall_moderate_high', hue='strategy', marker="o", ax=ax)
plt.title("Recall: Moderate to High", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Recall: Moderate to High')

# %%
ts_df.groupby(['strategy']).describe()
# Out:
#                                     list_size                               \
#                                         count  mean  std   min   25%   50%
# strategy
# Best Adjusted Metric - Adjusted          22.0  50.0  0.0  50.0  50.0  50.0
# Best Unadjusted Metric - Adjusted        22.0  50.0  0.0  50.0  50.0  50.0
# Best Unadjusted Metric - Unadjusted      22.0  50.0  0.0  50.0  50.0  50.0
#
#                                                 value                      \
#                                       75%   max count      mean       std
# strategy
# Best Adjusted Metric - Adjusted      50.0  50.0  22.0  0.557273  0.146716
# Best Unadjusted Metric - Adjusted    50.0  50.0  22.0  0.520000  0.147487
# Best Unadjusted Metric - Unadjusted  50.0  50.0  22.0  0.505455  0.165579
#
#                                                                      \
#                                       min     25%   50%   75%   max
# strategy
# Best Adjusted Metric - Adjusted      0.25  0.4625  0.60  0.62  0.77
# Best Unadjusted Metric - Adjusted    0.25  0.4250  0.52  0.54  0.77
# Best Unadjusted Metric - Unadjusted  0.22  0.4000  0.51  0.58  0.78
#
#                                     max_recall_ratio                      \
#                                                count      mean       std
# strategy
# Best Adjusted Metric - Adjusted                 22.0  5.068905  4.896151
# Best Unadjusted Metric - Adjusted               22.0  4.635371  2.675259
# Best Unadjusted Metric - Unadjusted             22.0  6.533707  4.816879
#
#                                                                               \
#                                           min       25%       50%        75%
# strategy
# Best Adjusted Metric - Adjusted      1.270078  1.301627  1.586543   9.120976
# Best Unadjusted Metric - Adjusted    1.270078  2.218332  5.016045   5.829516
# Best Unadjusted Metric - Unadjusted  1.272158  2.519153  6.484802  10.482781
#
#                                                recall_low_to_highest  \
#                                            max                 count
# strategy
# Best Adjusted Metric - Adjusted      13.460042                  10.0
# Best Unadjusted Metric - Adjusted    10.489286                  10.0
# Best Unadjusted Metric - Unadjusted  13.910066                  10.0
#
#                                                                              \
#                                          mean       std       min       25%
# strategy
# Best Adjusted Metric - Adjusted      1.715363  1.707846  0.894384  0.894384
# Best Unadjusted Metric - Adjusted    3.756002  2.498700  0.894384  0.894384
# Best Unadjusted Metric - Unadjusted  1.146289  0.710599  0.695143  0.695143
#
#                                                                    \
#                                           50%       75%       max
# strategy
# Best Adjusted Metric - Adjusted      0.916166  0.916166  4.955714
# Best Unadjusted Metric - Adjusted    4.955714  5.863462  6.172065
# Best Unadjusted Metric - Unadjusted  0.931650  0.931650  2.477857
#
#                                     recall_low_high                      \
#                                               count      mean       std
# strategy
# Best Adjusted Metric - Adjusted                10.0  2.173613  2.859579
# Best Unadjusted Metric - Adjusted              10.0  3.232117  2.595936
# Best Unadjusted Metric - Unadjusted            10.0  1.182734  0.711860
#
#                                                                              \
#                                           min       25%       50%       75%
# strategy
# Best Adjusted Metric - Adjusted      0.768269  0.768269  0.866477  0.866477
# Best Unadjusted Metric - Adjusted    0.866477  0.866477  3.414530  3.414530
# Best Unadjusted Metric - Unadjusted  0.823930  0.823930  0.866477  0.866477
#
#                                               recall_low_moderate            \
#                                           max               count      mean
# strategy
# Best Adjusted Metric - Adjusted      7.598571                10.0  2.863268
# Best Unadjusted Metric - Adjusted    7.598571                10.0  3.602390
# Best Unadjusted Metric - Unadjusted  2.532857                10.0  0.706305
#
#                                                                              \
#                                           std       min       25%       50%
# strategy
# Best Adjusted Metric - Adjusted      4.021548  0.813034  0.813034  1.100493
# Best Unadjusted Metric - Adjusted    3.703492  1.100493  1.100493  2.660839
# Best Unadjusted Metric - Unadjusted  0.303664  0.396959  0.396959  0.786066
#
#                                                          recall_moderate_high  \
#                                           75%        max                count
# strategy
# Best Adjusted Metric - Adjusted      1.100493  10.489286                 22.0
# Best Unadjusted Metric - Adjusted    2.660839  10.489286                 22.0
# Best Unadjusted Metric - Unadjusted  0.786066   1.165476                 22.0
#
#                                                                              \
#                                          mean       std       min       25%
# strategy
# Best Adjusted Metric - Adjusted      1.530379  1.714426  0.141912  0.740148
# Best Unadjusted Metric - Adjusted    1.809275  1.672591  0.283824  0.740148
# Best Unadjusted Metric - Unadjusted  1.015148  0.812615  0.071890  0.139991
#
#                                                                    \
#                                           50%       75%       max
# strategy
# Best Adjusted Metric - Adjusted      0.944941  1.164624  5.016045
# Best Unadjusted Metric - Adjusted    1.283253  2.218332  5.016045
# Best Unadjusted Metric - Unadjusted  1.102295  1.833432  2.173238
#
#                                     recall_moderate_highest            \
#                                                       count      mean
# strategy
# Best Adjusted Metric - Adjusted                        22.0  1.191328
# Best Unadjusted Metric - Adjusted                      22.0  1.488844
# Best Unadjusted Metric - Unadjusted                    22.0  1.977321
#
#                                                                              \
#                                           std       min       25%       50%
# strategy
# Best Adjusted Metric - Adjusted      1.196190  0.074294  0.537857  0.812713
# Best Unadjusted Metric - Adjusted    1.214982  0.174591  0.557519  1.135353
# Best Unadjusted Metric - Unadjusted  2.283550  0.095395  0.295665  1.185206
#
#
#                                           75%       max
# strategy
# Best Adjusted Metric - Adjusted      1.126848  3.568156
# Best Unadjusted Metric - Adjusted    2.290598  3.568156
# Best Unadjusted Metric - Unadjusted  2.032328  6.484802
